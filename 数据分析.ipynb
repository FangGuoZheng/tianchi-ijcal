# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
data = iris.data

# %%
df = pd.DataFrame({a[0]:data[:,0],a[1]:data[:,1],a[2]:data[:,2],a[3]:data[:,3],'Species':iris.target})

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='white',color_codes=True)

# %%
plt.scatter(x=iris.data[:,0],y=iris.data[:,1])
plt.show()

# %%
sns.jointplot(x=iris.data[:,0],y=iris.data[:,1],size=5)

# %%
plt.show()

# %%
sns.FacetGrid(df,hue='Species',size=5).map(plt.scatter,'sepal length (cm)','sepal width (cm)').add_legend()
plt.show()

# %%
sns.boxplot(x='Species',y='petal length (cm)',data=df)
plt.show()

# %%
ax=sns.boxplot(x='Species',y='petal length (cm)',data=df)
sns.stripplot(x='Species',y='petal length (cm)',data=df,jitter=True,edgecolor='gray')
plt.show()

# %%
sns.violinplot(x='Species',y='petal length (cm)',data=df,size=6)
plt.show()

# %%
sns.pairplot(df,hue='Species',size=3)
plt.show()

# %%
df.head()
# Out:
#    Species  petal length (cm)  petal width (cm)  sepal length (cm)  \
# 0        0                1.4               0.2                5.1
# 1        0                1.4               0.2                4.9
# 2        0                1.3               0.2                4.7
# 3        0                1.5               0.2                4.6
# 4        0                1.4               0.2                5.0
#
#    sepal width (cm)
# 0               3.5
# 1               3.0
# 2               3.2
# 3               3.1
# 4               3.6
